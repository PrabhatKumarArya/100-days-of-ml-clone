# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=90c431c7e582f8595c74eba6db36e230&language=en-US&page=1&sort_by=created_at.asc')

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#         id                     title  \
# 0  1632181       Accidental Partners
# 1  1007757                   Swapped
# 2      278  The Shawshank Redemption
# 3   936075                   Michael
# 4      238             The Godfather
#
#                                             overview release_date  popularity  \
# 0  Two women discover they were both scammed by t...   2026-03-12     27.4383
# 1  A small woodland creature and a majestic bird,...   2026-05-01     84.0481
# 2  Imprisoned in the 1940s for the double murder ...   1994-09-23    178.9021
# 3  The story of Michael Jackson, one of the most ...   2026-04-22    167.8226
# 4  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     39.6284
#
#    vote_average  vote_count
# 0         9.078         308
# 1         8.914        1933
# 2         8.725       30761
# 3         8.702        3504
# 4         8.687       23161

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/iCML6fBe3X0y06P33bM7dyYXPKZ.jpg',
#    'genre_ids': [35, 10749],
#    'id': 1632181,
#    'title': 'Accidental Partners',
#    'original_language': 'es',
#    'original_title': 'Socias por accidente',
#    'overview': 'Two women discover they were both scammed by the same man (who also got them pregnant). They form an alliance to take revenge.',
#    'popularity': 27.4383,
#    'poster_path': '/sr1Yoj6XLPTWYcbDoBy67xivW4I.jpg',
#    'release_date': '2026-03-12',
#    'softcore': False,
#    'video': False,
#    'vote_average': 9.078,
#    'vote_count': 308},
#   {'adult': False,
#    'backdrop_path': '/zMwhWailP1WY7sb6AoE6b8ugoy.jpg',
#    'genre_ids': [12, 16, 10751, 14],
#    'id': 1007757,
#    'title': 'Swapped',
#    'original_language': 'en',
#    'original_title': 'Swapped',
# ...

# %%
df = pd.DataFrame()

# %%
for i in range(1,551):
    response = requests.get(f"https://api.themoviedb.org/3/movie/top_rated?api_key=90c431c7e582f8595c74eba6db36e230&language=en-US&page={i}")
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#             id                            title  \
# 0      1632181              Accidental Partners
# 1      1007757                          Swapped
# 2          278         The Shawshank Redemption
# 3       936075                          Michael
# 4          238                    The Godfather
# ...        ...                              ...
# 19995    34746  Death Wish V: The Face of Death
# 19996    10075              Blood and Chocolate
# 19997   602211                           Fatman
# 19998   219318                      The Volcano
# 19999     2698                    Evan Almighty
#
#                                                 overview release_date  \
# 0      Two women discover they were both scammed by t...   2026-03-12
# 1      A small woodland creature and a majestic bird,...   2026-05-01
# 2      Imprisoned in the 1940s for the double murder ...   1994-09-23
# 3      The story of Michael Jackson, one of the most ...   2026-04-22
# ...

# %%
df.shape
# Out:
# (20000, 7)

# %%
df.to_csv('movies.csv')
