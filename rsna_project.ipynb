# %%
df = pd.read_csv(r"\Users\Anjli Kumari\datasets\rsna_train.csv")
df
# Out:
#                                        StudyInstanceUID  \
# 0     1.2.826.0.1.3680043.8.498.10004873229099053869...
# 1     1.2.826.0.1.3680043.8.498.10004945927472656027...
# 2     1.2.826.0.1.3680043.8.498.10009278692606631573...
# 3     1.2.826.0.1.3680043.8.498.10009639203170750274...
# 4     1.2.826.0.1.3680043.8.498.10013663742400736029...
# ...                                                 ...
# 4402  1.2.826.0.1.3680043.8.498.99880021280666757817...
# 4403  1.2.826.0.1.3680043.8.498.99881620336512626242...
# 4404  1.2.826.0.1.3680043.8.498.99926624968240681772...
# 4405  1.2.826.0.1.3680043.8.498.99939100657291954890...
# 4406  1.2.826.0.1.3680043.8.498.99957611207313098696...
#
#                                                  Report  ACL  MCL  \
# 0     Técnica: RMN de la rodilla. Resultados: Rotura...  NaN  NaN
# 1     [DATE]: * MR Knie Rechts 15ch AA Klinische Inl...  NaN  NaN
# 2     Hallazgos:\nNo hay alteraciones en significati...  NaN  NaN
# ...

# %%
df.shape
# Out:
# (4407, 14)

# %%
df.isnull().mean()*100
# Out:
# StudyInstanceUID     0.000000
# Report               0.000000
# ACL                 98.683912
# MCL                 98.683912
# Medial Meniscus     98.683912
# Lateral Meniscus    98.683912
# Medial OA           98.683912
# Lateral OA          98.683912
# PF OA               98.683912
# Effusion            98.683912
# Synovitis           98.683912
# Baker's             98.683912
# Contusion           98.683912
# Fracture            98.683912
# dtype: float64

# %%
df.describe()
# Out:
#              ACL        MCL  Medial Meniscus  Lateral Meniscus  Medial OA  \
# count  58.000000  58.000000        58.000000         58.000000  58.000000
# mean    0.413793   0.155172         0.448276          0.396552   0.258621
# std     0.496814   0.365231         0.501661          0.493454   0.441701
# min     0.000000   0.000000         0.000000          0.000000   0.000000
# 25%     0.000000   0.000000         0.000000          0.000000   0.000000
# 50%     0.000000   0.000000         0.000000          0.000000   0.000000
# 75%     1.000000   0.000000         1.000000          1.000000   0.750000
# max     1.000000   1.000000         1.000000          1.000000   1.000000
#
#        Lateral OA      PF OA   Effusion  Synovitis    Baker's  Contusion  \
# count   58.000000  58.000000  58.000000  58.000000  58.000000  58.000000
# mean     0.189655   0.362069   0.603448   0.465517   0.206897   0.327586
# std      0.395452   0.484796   0.493454   0.503166   0.408619   0.473432
# ...

# %%
df_copy = df.copy()

# %%
missing_values = df_copy['ACL'].isnull()
df_copy.loc[missing_values, 'ACL'] = df_copy['ACL'].dropna().sample(df_copy['ACL'].isnull().sum()).values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 missing_values = df_copy['ACL'].isnull()
# ----> 2 df_copy.loc[missing_values, 'ACL'] = df_copy['ACL'].dropna().sample(df_copy['ACL'].isnull().sum()).values
#
# File ~\anaconda3\envs\machine_learning\Lib\site-packages\pandas\core\generic.py:6000, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5996
#    5997         if weights is not None:
#    5998             weights = sample.preprocess_weights(self, weights, axis)
#    5999
# -> 6000         sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    6001         result = self.take(sampled_indices, axis=axis)
#    6002
#    6003         if ignore_index:
#
# ...

# %%
for col in df_copy.drop(columns=['StudyInstanceUID', 'Report']).columns:
    print(f"{col} Analytics")
    print("Missing:", df_copy[col].isnull().sum())
    print("Available:", df_copy[col].notnull().sum())
print(df_copy.drop(columns=['StudyInstanceUID', 'Report']).shape[1])
# Out:
# ACL Analytics
# Missing: 4349
# Available: 58
# MCL Analytics
# Missing: 4349
# Available: 58
# Medial Meniscus Analytics
# Missing: 4349
# Available: 58
# Lateral Meniscus Analytics
# Missing: 4349
# Available: 58
# Medial OA Analytics
# Missing: 4349
# Available: 58
# Lateral OA Analytics
# Missing: 4349
# Available: 58
# PF OA Analytics
# Missing: 4349
# Available: 58
# Effusion Analytics
# Missing: 4349
# Available: 58
# Synovitis Analytics
# Missing: 4349
# Available: 58
# Baker's Analytics
# Missing: 4349
# Available: 58
# Contusion Analytics
# Missing: 4349
# Available: 58
# Fracture Analytics
# Missing: 4349
# Available: 58
# 12

# %%
df.info(show_counts=np.nan)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4407 entries, 0 to 4406
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   StudyInstanceUID  4407 non-null   str
#  1   Report            4407 non-null   str
#  2   ACL               58 non-null     float64
#  3   MCL               58 non-null     float64
#  4   Medial Meniscus   58 non-null     float64
#  5   Lateral Meniscus  58 non-null     float64
#  6   Medial OA         58 non-null     float64
#  7   Lateral OA        58 non-null     float64
#  8   PF OA             58 non-null     float64
#  9   Effusion          58 non-null     float64
#  10  Synovitis         58 non-null     float64
#  11  Baker's           58 non-null     float64
#  12  Contusion         58 non-null     float64
#  13  Fracture          58 non-null     float64
# dtypes: float64(12), str(2)
# memory usage: 482.1 KB

# %%
df1 = pd.DataFrame([x.strip() for x in df['Report'][0].split('.') if x.strip()])
df1
# Out:
#                                                    0
# 0                         Técnica: RMN de la rodilla
# 1              Resultados: Rotura de menisco interno
# 2  Signo de necrosis avascular subcondral en el c...
# 3                       Artrosis femorotibial medial
# 4                                            Derrame
# 5               Impresión: Rotura de menisco interno
# 6  Signo de necrosis avascular subcondral en el c...
# 7                       Artrosis femorotibial medial
# 8                                            Derrame

# %%
df2 = pd.DataFrame(df['Report'].apply(lambda x: [s.strip() for s in str(x).split('.') if s.strip()]).tolist())
df2 = df2.iloc[0:,0:10]
df2
# Out:
#                                                       0  \
# 0                            Técnica: RMN de la rodilla
# 1     [DATE]: * MR Knie Rechts 15ch AA Klinische Inl...
# 2     Hallazgos:\nNo hay alteraciones en significati...
# 3     In the medial compartment, the meniscus is not...
# 4                CONSTATATIONS :\n\nFractures :\nAucune
# ...                                                 ...
# 4402  Exam Type: MRI KNEE RIGHT WO CONTRAST\nExam Da...
# 4403  [DATE]: *MR Knie Rechts 15ch AA Klinische Inli...
# 4404                                        SAĞ DİZ MRG
# 4405  MRI of Knee with \n-Locator, SG PD FatSat, SG ...
# 4406                         Técnica: RMN de la rodilla
#
#                                                       1  \
# 0                 Resultados: Rotura de menisco interno
# 1     Diagnostische vraagstellling: Meniscusscheur/m...
# 2     Ligamentos cruzados y colaterales dentro de lí...
# 3     The lateral compartment, there is suspicious i...
# ...

# %%
X_train,X_test,Y_train,Y_test = train(X,Y,0.2,42)
