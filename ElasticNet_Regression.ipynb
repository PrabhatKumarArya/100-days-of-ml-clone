# %%
from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet
from sklearn.metrics import r2_score

# %%
X,Y = load_diabetes(return_X_y=True)

# %%
X_train,X_test,Y_train,Y_test = train(X,Y,0.2,2)

# %%
lr = LinearRegression()
lr.fit(X_train,Y_train)
Y_pred = lr.predict(X_test)
r2_score(Y_test,Y_pred)
# Out:
# 0.439933866156897

# %%
rdg = Ridge(alpha=0.1)
rdg.fit(X_train,Y_train)
Y_pred1 = rdg.predict(X_test)
r2_score(Y_test,Y_pred1)
# Out:
# 0.45199494197195467

# %%
lso = Lasso(alpha=0.01)
lso.fit(X_train,Y_train)
Y_pred2 = lso.predict(X_test)
r2_score(Y_test,Y_pred2)
# Out:
# 0.44111855963110624

# %%
elsnet = ElasticNet(alpha=0.005,l1_ratio=0.9)
elsnet.fit(X_train,Y_train)
Y_pred3 = elsnet.predict(X_test)
r2_score(Y_test,Y_pred3)
# elasticnet can also be implemented using sgdregressor class by penalty = elasticnet(preferable - ElasticNet Class)
# Out:
# 0.4531474541554823
