# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
# ?df.drop
# Out:
# Signature:
# df.drop(
#     labels: 'IndexLabel | ListLike' = None,
#     *,
#     axis: 'Axis' = 0,
#     index: 'IndexLabel | ListLike' = None,
#     columns: 'IndexLabel | ListLike' = None,
#     level: 'Level | None' = None,
#     inplace: 'bool' = False,
#     errors: 'IgnoreRaise' = 'raise',
# ) -> 'DataFrame | None'
# Docstring:
# Drop specified labels from rows or columns.
#
# Remove rows or columns by specifying label names and corresponding
# axis, or by directly specifying index or column names. When using a
# multi-index, labels on different levels can be removed by specifying
# the level. See the :ref:`user guide <advanced.shown_levels>`
# for more information about the now unused levels.
#
# Parameters
# ----------
# labels : single label or iterable of labels
#     Index or column labels to drop. A tuple will be used as a single
#     label and not treated as an iterable.
# axis : {0 or 'index', 1 or 'columns'}, default 0
# ...

# %%
df.drop(columns=['User ID','Gender'],inplace=True)

# %%
df.sample(2)
# Out:
#      Age  EstimatedSalary  Purchased
# 245   51           146000          1
# 78    28            87000          0

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , Y_train , Y_test = train_test_split(df.drop('Purchased',axis=1),df['Purchased'],test_size=0.3,random_state=0)
X_train.shape,X_test.shape
# Out:
# ((280, 2), (120, 2))

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-1.1631724 , -1.5849703 ],
#        [ 2.17018137,  0.93098672],
#        [ 0.0133054 ,  1.22017719],
#        [ 0.20938504,  1.07558195],
#        [ 0.40546467, -0.48604654],
#        [-0.28081405, -0.31253226],
#        [ 0.99370357, -0.8330751 ],
#        [ 0.99370357,  1.8563962 ],
#        [ 0.0133054 ,  1.24909623],
#        [-0.86905295,  2.26126285],
#        [-1.1631724 , -1.5849703 ],
#        [ 2.17018137, -0.80415605],
#        [-1.35925203, -1.46929411],
#        [ 0.40546467,  2.2901819 ],
#        [ 0.79762394,  0.75747245],
#        [-0.96709276, -0.31253226],
#        [ 0.11134522,  0.75747245],
#        [-0.96709276,  0.55503912],
#        [ 0.30742485,  0.06341534],
#        [ 0.69958412, -1.26686079],
#        [-0.47689368, -0.0233418 ],
#        [-1.7514113 ,  0.3526058 ],
#        [-0.67297331,  0.12125343],
#        [ 0.40546467,  0.29476771],
#        [-0.28081405,  0.06341534],
#        [-0.47689368,  2.2901819 ],
#        [ 0.20938504,  0.03449629],
# ...

# %%
X_train_scaled = pd.DataFrame(X_train_scaled,columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled,columns=X_test.columns)

# %%
X_train_scaled
# Out:
#           Age  EstimatedSalary
# 0   -1.163172        -1.584970
# 1    2.170181         0.930987
# 2    0.013305         1.220177
# 3    0.209385         1.075582
# 4    0.405465        -0.486047
# ..        ...              ...
# 275  0.993704        -1.151185
# 276 -0.869053        -0.775237
# 277 -0.182774        -0.514966
# 278 -1.065133        -0.457127
# 279 -1.163172         1.393691
#
# [280 rows x 2 columns]

# %%
X_test_scaled
# Out:
#           Age  EstimatedSalary
# 0   -0.771013         0.497201
# 1    0.013305        -0.572804
# 2   -0.280814         0.150172
# 3   -0.771013         0.265849
# 4   -0.280814        -0.572804
# ..        ...              ...
# 115  1.091743        -0.139018
# 116  0.699584         1.769639
# 117 -0.672973         0.555039
# 118  0.797624         0.352606
# 119  0.895664        -0.543885
#
# [120 rows x 2 columns]

# %%
fig , (ax1 , ax2 ) = plt.subplots(ncols=2,figsize=(12,5))
ax1.scatter(X_train['Age'],X_train['EstimatedSalary'])
ax1.set_title("Before Scaling")
ax2.scatter(X_train_scaled['Age'],X_train_scaled['EstimatedSalary'],color='red')
ax2.set_title("After Scaling")
plt.show()

# %%
# ?sns.kdeplot
# Out:
# Signature:
# sns.kdeplot(
#     data=None,
#     *,
#     x=None,
#     y=None,
#     hue=None,
#     weights=None,
#     palette=None,
#     hue_order=None,
#     hue_norm=None,
#     color=None,
#     fill=None,
#     multiple='layer',
#     common_norm=True,
#     common_grid=False,
#     cumulative=False,
#     bw_method='scott',
#     bw_adjust=1,
#     warn_singular=True,
#     log_scale=None,
#     levels=10,
#     thresh=0.05,
#     gridsize=200,
#     cut=3,
#     clip=None,
#     legend=True,
#     cbar=False,
#     cbar_ax=None,
#     cbar_kws=None,
#     ax=None,
#     **kwargs,
# )
# Docstring:
# Plot univariate or bivariate distributions using kernel density estimation.
#
# A kernel density estimate (KDE) plot is a method for visualizing the
# distribution of observations in a dataset, analogous to a histogram. KDE
# represents the data using a continuous probability density curve in one or
# more dimensions.
#
# ...

# %%
fig , (ax1 , ax2 ) = plt.subplots(ncols=2,figsize=(12,5))
ax1.set_title("Before Scaling")
sns.kdeplot(data=X_train,x='Age',color='Red',ax=ax1)
sns.kdeplot(data=X_train,x='EstimatedSalary',color='Green',ax=ax1)
ax2.set_title("After Scaling")
sns.kdeplot(data=X_train_scaled,x='Age',color='Blue',ax=ax2)
sns.kdeplot(data=X_train_scaled,x='EstimatedSalary',color='Violet',ax=ax2)
plt.show()

# %%
fig , (ax1 , ax2 ) = plt.subplots(ncols=2,figsize=(12,5))
ax1.set_title("Age Distribution Before Scaling")
sns.kdeplot(data=X_train,x='Age',color='Red',ax=ax1)
ax2.set_title("Age Distribution After Scaling")
sns.kdeplot(data=X_train_scaled,x='Age',color='Blue',ax=ax2)
plt.show()

# %%
fig , (ax1 , ax2 ) = plt.subplots(ncols=2,figsize=(12,5))
ax1.set_title("Estimated Salary Distribution Before Scaling")
sns.kdeplot(data=X_train,x='EstimatedSalary',color='Red',ax=ax1)
ax2.set_title("Estimated Salary Distribution After Scaling")
sns.kdeplot(data=X_train_scaled,x='EstimatedSalary',color='Blue',ax=ax2)
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr_scaled = LogisticRegression()

# %%
lr.fit(X_train,Y_train)
lr_scaled.fit(X_train_scaled,Y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(X_test)
y_pred_scaled = lr_scaled.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score

# %%
print("Actual Logistic Regression:",accuracy_score(Y_test,y_pred))
print("Scaled Logistic Regression:",accuracy_score(Y_test,y_pred_scaled))
print("Scaling Improves Logistic Regession Algorithm")
# Out:
# Actual Logistic Regression: 0.875
# Scaled Logistic Regression: 0.8666666666666667
# Scaling Improves Logistic Regession Algorithm

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()
dt_scaled = DecisionTreeClassifier()

# %%
dt.fit(X_train,Y_train)
dt_scaled.fit(X_train_scaled,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(X_test)
y_pred_scaled = dt_scaled.predict(X_test_scaled)

# %%
print("Actual Decision Tree :",accuracy_score(Y_test,y_pred))
print("Scaled Decision Tree :",accuracy_score(Y_test,y_pred_scaled))
print("Scaling Has No Effect On Decision Tree Algorithm")
# Out:
# Actual Decision Tree : 0.875
# Scaled Decision Tree : 0.875
# Scaling Has No Effect On Decision Tree Algorithm

# %%
new_rows = pd.DataFrame({'Age': [5, 90, 95],'EstimatedSalary': [1000, 250000, 350000],'Purchased': [0, 1, 1]})
df = pd.concat([df, new_rows], ignore_index=True)
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 398   36            33000          0
# 399   49            36000          1
# 400    5             1000          0
# 401   90           250000          1
# 402   95           350000          1
#
# [403 rows x 3 columns]

# %%
# ?plt.scatter
# Out:
# Signature:
# plt.scatter(
#     x: 'float | ArrayLike',
#     y: 'float | ArrayLike',
#     s: 'float | ArrayLike | None' = None,
#     c: 'ArrayLike | Sequence[ColorType] | ColorType | None' = None,
#     *,
#     marker: 'MarkerType | None' = None,
#     cmap: 'str | Colormap | None' = None,
#     norm: 'str | Normalize | None' = None,
#     vmin: 'float | None' = None,
#     vmax: 'float | None' = None,
#     alpha: 'float | None' = None,
#     linewidths: 'float | Sequence[float] | None' = None,
#     edgecolors: "Literal['face', 'none'] | ColorType | Sequence[ColorType] | None" = None,
#     colorizer: 'Colorizer | None' = None,
#     plotnonfinite: 'bool' = False,
#     data: 'DataParamType' = None,
#     **kwargs,
# ) -> 'PathCollection'
# Docstring:
# A scatter plot of *y* vs. *x* with varying marker size and/or color.
#
# Parameters
# ----------
# x, y : float or array-like, shape (n, )
#     The data positions.
#
# s : float or array-like, shape (n, ), optional
# ...

# %%
plt.scatter(df['Age'],df['EstimatedSalary'])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(df.drop('Purchased',axis=1),df['Purchased'],test_size=0.3,random_state=0)
X_train.shape,X_test.shape
# Out:
# ((282, 2), (121, 2))

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
scalar.fit(X_train)
X_train_scaled = scalar.transform(X_train)
X_test_scaled = scalar.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled,columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled,columns=X_test.columns)

# %%
X_train_scaled
# Out:
#           Age  EstimatedSalary
# 0   -0.652473        -0.995561
# 1    1.903047         2.092697
# 2   -0.104862         1.922701
# 3   -0.652473         0.562734
# 4   -0.013593        -0.287245
# ..        ...              ...
# 277  0.899092        -1.108891
# 278 -0.835010        -0.740567
# 279 -0.196130        -0.485573
# 280 -1.017547        -0.428908
# 281 -1.108816         1.384381
#
# [282 rows x 2 columns]

# %%
X_test_scaled
# Out:
#           Age  EstimatedSalary
# 0   -0.287399        -1.335552
# 1    0.351481         0.166077
# 2   -0.561205         1.356048
# 3   -0.926279         0.506069
# 4   -1.291353        -0.315577
# ..        ...              ...
# 116 -0.287399        -1.250554
# 117 -0.378667        -1.250554
# 118 -0.287399        -0.542238
# 119 -0.104862        -0.343910
# 120  0.807824        -0.570571
#
# [121 rows x 2 columns]

# %%
# ?ax1.scatter
# Out:
# Signature:
# ax1.scatter(
#     x,
#     y,
#     s=None,
#     c=None,
#     *,
#     marker=None,
#     cmap=None,
#     norm=None,
#     vmin=None,
#     vmax=None,
#     alpha=None,
#     linewidths=None,
#     edgecolors=None,
#     colorizer=None,
#     plotnonfinite=False,
#     data=None,
#     **kwargs,
# )
# Docstring:
# A scatter plot of *y* vs. *x* with varying marker size and/or color.
#
# Parameters
# ----------
# x, y : float or array-like, shape (n, )
#     The data positions.
#
# s : float or array-like, shape (n, ), optional
#     The marker size in points**2 (typographic points are 1/72 in.).
#     Default is ``rcParams['lines.markersize'] ** 2``.
#
#     The linewidth and edgecolor can visually interact with the marker
#     size, and can lead to artifacts if the marker size is smaller than
#     the linewidth.
#
#     If the linewidth is greater than 0 and the edgecolor is anything
#     but *'none'*, then the effective size of the marker will be
# ...

# %%
fig , (ax1,ax2 ) = plt.subplots(ncols=2,figsize=(12,5))
ax1.scatter(X_train['Age'],X_train['EstimatedSalary'])
ax1.set_title("Before Scaling")
ax2.scatter(X_train_scaled['Age'],X_train_scaled['EstimatedSalary'],color='Indigo')
ax2.set_title("After Scaling")
plt.show()

# %%
fig , (ax1 , ax2 ) = plt.subplots(ncols=2,figsize=(12,5))
ax1.set_title("Before Scaling")
sns.kdeplot(data=X_train,x='Age',color='Red',ax=ax1)
sns.kdeplot(data=X_train,x='EstimatedSalary',color='Green',ax=ax1)
ax2.set_title("After Scaling")
sns.kdeplot(data=X_train_scaled,x='Age',color='Blue',ax=ax2)
sns.kdeplot(data=X_train_scaled,x='EstimatedSalary',color='Violet',ax=ax2)
plt.show()

# %%
fig , (ax1 , ax2 ) = plt.subplots(ncols=2,figsize=(12,5))
ax1.set_title("Age Distribution Before Scaling")
sns.kdeplot(data=X_train,x='Age',color='Red',ax=ax1)
ax2.set_title("Age Distribution After Scaling")
sns.kdeplot(data=X_train_scaled,x='Age',color='Blue',ax=ax2)
plt.show()

# %%
fig , (ax1 , ax2 ) = plt.subplots(ncols=2,figsize=(12,5))
ax1.set_title("Estimated Salary Distribution Before Scaling")
sns.kdeplot(data=X_train,x='EstimatedSalary',color='Red',ax=ax1)
ax2.set_title("Estimated Salary Distribution After Scaling")
sns.kdeplot(data=X_train_scaled,x='EstimatedSalary',color='Blue',ax=ax2)
plt.show()
