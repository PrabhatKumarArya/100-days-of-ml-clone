# %%
df = pd.read_csv(r"\Users\Anjli Kumari\datasets\data.csv")
df.head()
# Out:
#    feature1  feature2  feature3     target
# 0 -0.570563  1.420342  0.495580  -9.763182
# 1 -0.990563  0.556965  1.045064 -24.029355
# 2 -0.674728  0.150617  1.774645  45.616421
# 3  0.388250 -0.387127 -0.110229  34.135737
# 4  1.167882 -0.024104  0.145063  86.663647

# %%
X = df.iloc[:,0:3].values
Y = df.iloc[:,-1].values

# %%
X_train,X_test,Y_train,Y_test = train(X,Y,0.3,1)

# %%
lr = LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### 1.Linear Relationship

# %%
Y_pred = lr.predict(X_test)

# %%
residual = Y_pred - Y_test

# %%
fig , (ax1,ax2,ax3) = plt.subplots(ncols=3,figsize=(12,2.5))
ax1.scatter(df['feature1'],df['target'])
ax1.set_title('Feature1')
ax2.scatter(df['feature2'],df['target'])
ax2.set_title('Feature2')
ax3.scatter(df['feature3'],df['target'])
ax3.set_title('Feature3')
plt.show()

# %% [markdown]
# #### 2.Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vlf = []
for i  in range(X_train.shape[1]):
    vlf.append(variance_inflation_factor(X_train,i))

# %%
pd.DataFrame({"vlf":vlf},index=df.columns[0:3]).T
# Out:
#      feature1  feature2  feature3
# vlf  1.010326  1.009871   1.01395

# %%
sns.heatmap(df.iloc[:,0:3].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# #### 3.Normal Residual

# %%
sns.displot(residual,kind='kde')

# %%
import scipy as sp
fig,ax = plt.subplots(figsize=(6,4))
sp.stats.probplot(residual,plot=ax,fit=True)
plt.show()

# %% [markdown]
# #### 4.Homescedasticity

# %%
plt.scatter(Y_pred,residual)

# %% [markdown]
# #### 5.No AutoCorrelation Of Error

# %%
plt.plot(residual)
