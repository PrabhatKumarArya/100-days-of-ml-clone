# %%
df = pd.read_csv(r"\Users\Anjli Kumari\datasets\placement.csv")
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package In LPA')
plt.show()

# %%
X = df.iloc[:,0:1]
Y = df.iloc[:,1]

# %%
Y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
X_train,X_test,Y_train,Y_test = train(X,Y,0.2,2)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package In LPA')
# Out:
# Text(0, 0.5, 'Package In LPA')

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
Y_pred = lr.predict(X_test)

# %%
print(f"MAE: {mean_absolute_error(Y_test,Y_pred)} LPA")
# Out:
# MAE: 0.2884710931878175 LPA

# %%
print(f"MSE: {mean_squared_error(Y_test,Y_pred)}")
# Out:
# MSE: 0.12129235313495527

# %%
print(f"RMSE: {np.sqrt(mean_squared_error(Y_test,Y_pred))} LPA")
# Out:
# RMSE: 0.34827051717731616 LPA

# %%
print(f"R2 Score: {r2_score(Y_test,Y_pred)}")
r2 = r2_score(Y_test,Y_pred)
# Out:
# R2 Score: 0.780730147510384

# %%
# Adjusted R2 Score
X_test.shape
# Out:
# (40, 1)

# %%
print(f"Adjusted R2 Score: {1 - ((1-r2)*(40-1)/(40-1-1))}")
# Out:
# Adjusted R2 Score: 0.7749598882343415

# %%
new_df1 = df.copy()
new_df1['random_feature'] = np.random.random(200)
new_df1 = new_df1[['cgpa','random_feature','package']]
new_df1.head()
# Out:
#    cgpa  random_feature  package
# 0  6.89        0.318984     3.26
# 1  5.12        0.044446     1.98
# 2  7.82        0.146901     3.25
# 3  7.42        0.477779     3.67
# 4  6.94        0.268496     3.57

# %%
plt.scatter(new_df1['random_feature'],new_df1['package'])
plt.xlabel('Random Features')
plt.ylabel('Package(In LPA)')
plt.show()

# %%
X = new_df1.iloc[:,0:2]
Y = new_df1.iloc[:,-1]

# %%
X_train,X_test,Y_train,Y_test = train(X,Y,0.2,2)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = lr.predict(X_test)

# %%
print(f"R2 Score: {r2_score(Y_test,Y_pred)}")
r2 = r2_score(Y_test,Y_pred)
# Out:
# R2 Score: 0.7822075548338351

# %%
print(f"Adjusted R2 Score: {1 - ((1-r2)*(40-1)/(40-2-1))}")
# Out:
# Adjusted R2 Score: 0.7704349902302586

# %%
new_df2 = df.copy()
new_df2['iq'] = new_df2['package'] + (np.random.randint(-12,12,200)/10)
new_df2 = new_df2[['cgpa','iq','package']]

# %%
new_df2.sample(5)
# Out:
#      cgpa    iq  package
# 190  6.19  2.99     2.69
# 45   7.87  2.88     3.58
# 168  8.65  3.52     3.52
# 187  6.26  3.44     2.44
# 50   9.58  3.53     4.43

# %%
plt.scatter(new_df2['iq'],new_df2['package'])
plt.xlabel('iq')
plt.ylabel('Package (In LPA)')
plt.show()

# %%
X = new_df2.iloc[:,0:2]
Y = new_df2.iloc[:,-1]

# %%
X_train,X_test,Y_train,Y_test = train(X,Y,0.2,2)

# %%
lr = LinearRegression()
lr.fit(X_train,Y_train)
Y_pred = lr.predict(X_test)

# %%
print(f"R2 Score: {r2_score(Y_test,Y_pred)}")
r2 = r2_score(Y_test,Y_pred)
# Out:
# R2 Score: 0.816948524537956

# %%
print(f"Adjusted R2 Score: {1 - ((1-r2)*(40-1)/(40-1-2))}")
# Out:
# Adjusted R2 Score: 0.8070538501886563
